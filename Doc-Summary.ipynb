# %%
import boto3
import json
import sys

# %%
#Document summarization

client = boto3.client('bedrock-runtime', region_name='us-east-1')
prompt = """
Human:Summarize the below paragraph in 10 sentences:
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 1 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
1.0 PURPOSE
The purpose of this GOP is to evaluate, facilitate rapid escalation and disseminate to Takeda
leaders and relevant functions, significant supply issues, as defined in this document, so that
appropriate decisions can be made to identify risk to patients and customers and determine the
appropriate course of remediation, comply with regulatory reporting requirements and identify
actions to correct and/or prevent the recurrence of the issue.
2.0 SCOPE
Regions, This GOP applies to all LOCs (all regions) having supplies from Takeda
Functional Areas, manufacturing site(s) as well as External Supply. The procedure also applies to
Job Functions Supplying units within GMS delivering products to LOCs (and/or intercompany
sites) and global functions supporting order/delivery and planning processes
worldwide.
Applications This GOP applies to all Takeda entities and functions involved in supply of
Commercialized products and medical devices approved by relevant authorities
in the country where the product is supplied.
A SDN Incident is defined as an issue which:
 May impact continuity of supply to patients and customers
The inputs to the Supply Disruption Notification Process include the following:
 Supply issues arising from quality and compliance events and as such
controlled by the Quality Incident Management Process ref. SOP PROC-
001397 after or during each of the process steps in that procedure.
 Supply issues arising from non-quality events e.g. manufacturing
capacity limitations, demand forecasting discrepancies, technical
breakdowns, etc.
Limitations  Shortage and supply issues due to cessation of commercial activities.
 Where known limitations in Takeda’s capacity and/or ability to supply
was communicated to authorities.
 CMB Business
 This operating procedure does not cover GxP requirements directly as
these are handled and described within PROC-0001397.
3.0 DELEGATION OF ACTIVITIES
Activities in scope of this GOP may be delegated to an individual with the proper education,
experience and training to successfully execute the activity. The responsible party retains full
responsibility for the outcome of any delegated activity.
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 2 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
4.0 PROCEDURE
During the continuing manufacturing and supply planning activities including observations of
inventory levels and inventory level projections of Takeda owned inventory the parties
involved must continuously evaluate and estimate potential risks for supply disruptions.
Supply disruptions are defined in case Takeda can’t meet accepted and expected customer
order dates and/or quantities and such inability to supply is reasonable to believe will cause
issues for patients and customers and/or could require communication to relevant authorities.
4.1. DISCOVER AND FILE WATCHLIST
Number Responsibility Activity
4.1.1 OpU / Supplying Routinely (daily/weekly/monthly) check ability to meet current and
site / External estimated future customer demands by utilizing planning systems in
Supply / GSC place and updating and maintaining data used for supply planning
and inventory projections as well as information obtained from other
functions that could influence the ability to meet customer demand.
4.1.2 LOC’s Routinely (daily/weekly/monthly) monitor customer ordering as well
as market development to discover significant changes in market
consumptions that are not captured in current forecasts and plans.
Significant changes from plans/forecast should be reported to the
supplying unit of the finished product without delay.
4.1.3 OpU / Supplying Evaluate incoming and current alerts based on latest information /
site / External best estimates utilizing available supply systems (SAP IBP, JDE,
Supply etc). Using this information in tandem with the global criteria for
trigging disruption communications (Appendix 3) alerts must be
classified as a “Watchlist” item. The watchlist is maintained on the
SDN SharePoint site, and is communicated weekly via GMS
leadership reporting, and monthly via Regional S&OP and Pre-
S&OP meetings.
Identified Watchlists must be constantly monitored, with SharePoint
updated and escalated utilizing current management structures in
place (Site Leadership teams, OpU/GMS Regional Leadership team,
GMS leadership team, GMS Officer). Escalation needs to happen
according to sound judgements and guidelines as laid out in
Template 1. Watchlists escalated to OpU/Regional GMS level must
be filed in Template 2 and without delay reported to Global Supply
Planning team.
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 3 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
Number Responsibility Activity
4.1.4 Global Supply Maintain repository of all WatchList items (SharePoint / Qlik) and
Chain / SDN weekly issue list of all open WatchList items escalated to OpU/GMS
Organization Regional level and communicate to relevant stakeholders in GMS.
Facilitate weekly update and the progress of WatchList items.
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 4 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
4.2. IDENTIFY AND FILE SDN OR CONVERT WATCHLIST INTO SDN
Number Responsibility Activity
4.2.1 OpU / Supplying Proposal of Supply Disruption Notification
unit / External
Supply If the finished goods supplying unit can’t meet accepted and
expected customer order dates and/or quantities and such inability
SDN Owner
to supply is reasonable to believe will cause issues for patients and
customers and/or could require communication to relevant
authorities a proposal for a Supply Disruption Notification (SDN)
must be issued without delay and shared with Global Supply Chain
Planning Team.
To further clarify expectations in a MTS and MTO environments –
the SDN owner must assess the current situation against the global
criteria for trigging disruption communications (Appendix 3) to
determine if the SDN is needed.
The SDN proposal (structure defined in Appendix 4) must be as
minimum be approved by the Site Leadership team. Further
escalation and/or pre-approval steps needs to happen in case (more
than one can apply):
- The SDN is estimated to have significant patient and/or
customer impact. Consultation with GMS Officer, OpU /
Regional GMS Leader and Head of GSC is needed.
- The SDN is evaluated to require official contact and
communication to local authorities and field actions for
countries in scope. Consultation with Quality Incident
Management Group as well as LOC Regulatory and Quality
responsible persons is needed.
- The SDN originate from a Quality incident. In such case the
Quality Incident Group must be consulted.
- In case Takeda is not the Marketing Authorization holder
and/or Takeda acts as a CMO the relevant contract owner
within Takeda must be contacted for pre-approval
The proposed SDN must be verified and agreed according to the
above guidelines during meetings scheduled and prepared by the
Supplying unit.
In case of escalated approval and endorsement has been used
establishing the proposal the highest-ranking GMS member must
finally endorse recommendation.
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 5 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
Number Responsibility Activity
4.2.2. Quality Incident Facilitate communication between the LOC Quality organization and
Group Site Quality organization and ensure appropriate and verified quality
language is applied in the SDN proposal.
Eventual escalation within the Quality organization is also handled
by the QIM Group.
Provide guidance if market or field actions will be required because
of the estimated supply defect as outlined in the proposed SDN.
4.2.3 LOC Regulatory Verify proposed SDN’s with regards to potential contact to
/ Quality / SC authorities:
function
Evaluate and comment if potential medical alternatives would be
available for patients by involving local medical functions in case this
becomes relevant.
SDN’s not originating from a Quality Incident (QI) that is estimated to
require field action must be verified before issued by the impacted
LOC’s functions responsible for the contact to relevant authorities.
In exceptional circumstances, it may be necessary for the LOC to
issue the SDN for supply events occurring solely in country and for
an extensive period of time.
4.2.4 Supply Planning Verify demand and supply assumptions used in the SDN proposal
(OpU, GMS
Region) Facilitate and ensure adherence to process.
File SDN in repository (SharePoint / Qlik) and provide regular
update to open SDN’s.
If disruption is beyond 1 month away, identify appropriate S&OP
level (Pre / Region / Global) and initiate S&OP discussions are
taking place at correct level until the supply issue is resolved. For
near-term disruptions, and ad hoc SDN meeting is required to
discuss options and necessary actions.
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 6 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
Number Responsibility Activity
4.2.5 OpU / Supplying Either the finished goods supplying site, packaging site, or
unit / External Operating Unit is the SDN owner – the decision between these
Supply options is owned by Operating Unit leadership. If a significant issue
SDN Owner takes place upstream (before FG), a SDN may be owned by the
upstream site team.
Submit and communicate approved SDN to relevant stakeholders in
GMS/GQ and Commercial Regions and Business Units according to
following guidelines (Distribution list in Appendix 5):
- Significant patient and/or customer impact SDN’s. GMS
Officer will communicate directly to TET members –
including the Chief Medical Officer.
- Communication to LOC supply chain responsible with
request to communicate further in own LOC to minimum
General Manager, Finance Manager, Regulatory
responsible and Quality Responsible.
- Communication within own OpU / Supplying Unit / External
Supply to all management levels starting from Site Supply
Chain functions upwards.
- Communicate to GSC functions involved and as minimum to
Global Planning, Regional Supply Chain Coordination and
Global Distribution and Logistics.
- For SDN’s originating from QI communication to QIM Group,
Site Quality Head and LOC Quality head.
- For non-quality SDN’s having Field Actions to LOC
regulatory and LOC Quality responsible.
4.3. TRACK AND TRACE SDN
Number Responsibility Activity
4.3.1 OpU / Supplying Regularly provide updates on the progress of the supply mitigations
unit / External and the assumptions associated with these to members that was
Supply initially receiving the SDN. Updates must be shared in scheduled
SDN Owner meetings with relevant functions or via written communication.
In case of worsening situations, a sound judgement, provided
guidelines in Template 1 and sense of urgency must be applied and
escalation paths should be utilized as described in section 4.2.
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 7 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
Number Responsibility Activity
4.3.2 Global Supply Facilitate S&OP discussions and escalations according to valid
Planning (GSP) process and ensure proper communication between Supplying Site
Regional Supply and Commercial organization.
Chain
Coordination GSP will lead Global S&OP Process meetings in case supply
(RSCC) defects will lead to escalations or a need for global allocation
decision.
Potential regional allocation decisions will be facilitated in the
Regional S&OP process lead by RSCC
4.3.3 Global Supply Monthly reconcile all open SDN’s and eventually associated Quality
Planning Incidents with QIM Group
Monitor progress and resolution of open SDN’s and issue monthly
status and performance reports.
4.4. REPORT AND CLOSE SDN
Number Responsibility Activity
4.4.1 OpU / Supplying Once the re-supply and future supply is ensured the SDN Owner
unit / External must communicate and report the SDN as closed including
Supply commenting on the corrective actions and preventive actions
SDN Owner defined.
5.0 TAKEDA DOCUMENT REFERENCES
Document ID Title
PROC-0001397 Global Quality Incident Management
6.0 APPENDICES
Appendix ## (Title)
1 RACI Matrix
2 FY2020 Core Products List
Global Low Coverage Criteria for Initiating Disruption Communications
3
SDN Template FY2020
4
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 8 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
7.0 REVISION HISTORY
Version Date Owner Description of Changes
1.0 June, 2019 Schuyler Fairfield Original Version
February,
2.0 John Buenger Revised to fit enhancements to process
2021
8.0 FORM
Name of Form,
Form ##
(Form Number: GMS-AA-BBB ver.x.y FRM C ver.p.q)
N/A N/A
9.0 TEMPLATE
Name of Template
Template ##
(Template Number: GMS-25-GSC ver.1.0 TPL D ver.1.0)
1 Supply Disruption Notification template for content
2 Watchlist and SDN file
Document Owner:
11-May-2021 | 21:25 JST
_______________________ ___________________________
Schuyler Fairfield Date (DD.MM.YYYY)
Head of Global Supply Chain
Approver:
11-May-2021 | 23:13 JST
_______________________ ___________________________
Thomas Wozniewski Date (DD.MM.YYYY)
Global Manufacturing and
Supply Officer
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 9 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
APPENDICES
1: RACI Matrix SDN
2: FY2020 Core Products List
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 10 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
3: Global Low Coverage Criteria for Initiating Disruption Communications (SDN /
Watchlist)
4: SDN Template
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.
DocuSign Envelope ID: 34E2C9D1-C67F-409E-88DB-B34580166F3D
GMS OPERATING PROCEDURE
GOP Number: GMS-25-GSC Page: 11 of 11
Version Number: 2.0
This version replaces: 1.0
Parent Document:
GOP Title: Supply Disruption Notification
5: SDN Distribution Stakeholder Groups / Distribution List:
Printed or downloaded documents must be verified against the effective version.
CONFIDENTIAL INFORMATION
Do not distribute outside of Takeda without GMS SPINE approval or a confidentiality agreement.

Assistant:"""

try:
    response = client.invoke_model(
        body = bytes(json.dumps({
            "prompt":prompt ,
            "max_tokens_to_sample": 2048,
            "temperature": 1.0,
            "top_k": 250,
            "top_p": 0.9,
            "stop_sequences": [
            "\\n\\nHuman:"
            ],
            "anthropic_version": "bedrock-2023-05-31"
        }), 'utf-8'),
        modelId = "anthropic.claude-v2",
        contentType = "application/json",
        accept = "application/json"
    )
    response_text = response['body'].read().decode('utf8').strip()
    response_json = json.loads(response_text)
    completion = response_json['completion']
    print('\033[97;40m' + completion + '\033[0m')
except Exception as e:
    print('Error invoking endpoint')
    print(e)
    sys.exit(1)
